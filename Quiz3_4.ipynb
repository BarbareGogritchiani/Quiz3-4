# %% [markdown]
# <a href="https://colab.research.google.com/github/BarbareGogritchiani/Quiz3-4/blob/main/Quiz3_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Earthquakes_database.csv')
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1/2/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1/4/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1/5/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1/8/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1/9/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.drop_duplicates(inplace=True)
df #შლის ერთნაირ სტრიქონებს
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1/2/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1/4/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1/5/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1/8/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1/9/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.Date = df.Date.str.replace('/','.')
df #თარიღში / ჩანაცვლდება .-ით
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1.2.1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1.4.1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1.5.1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1.8.1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1.9.1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12.28.2016   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12.28.2016   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12.28.2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12.29.2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12.30.2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
import numpy as np

# %%
df = df.replace('Nan','')
df = df.replace('', np.nan)
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1.2.1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1.4.1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1.5.1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1.8.1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1.9.1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12.28.2016   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12.28.2016   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12.28.2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12.29.2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12.30.2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.Depth.value_counts() #ამ სვეტში წარმოდგენილი ვერსიების რაოდენობას სათითაოდ
# Out:
# Depth
# 10.000     3911
# 33.000     3694
# 35.000      592
# 15.000      384
# 20.000      336
#            ...
# 9.856         1
# 146.400       1
# 135.700       1
# 454.000       1
# 11.940        1
# Name: count, Length: 3485, dtype: int64

# %%
bins = [0, 50, 100, 400, 700]
labels = ['Shallow', 'Intermediate', 'Deep', 'Very Deep']
df.Category = pd.cut(df.Depth, bins=bins, labels=labels)
df # 0-50მდე ზედაპირული , 50-100 საშუალო, 100-400 ღრმა , 400-700მდე ძალიან ღრმა (კატეგორიებად დავყავი)
# Out:
# <ipython-input-15-1ae5c0552f5a>:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.Category = pd.cut(df.Depth, bins=bins, labels=labels)
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1.2.1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1.4.1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1.5.1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1.8.1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1.9.1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12.28.2016   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12.28.2016   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12.28.2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# ...

# %%
pivot_df = pd.pivot_table(df, values=['Magnitude', 'Depth'], index='Type', columns='Date', aggfunc='mean')
pivot_df # დროის მიხედვით მომხდარი მიწისძვრების სიღრმე და მაგნიტუდა
# Out:
#                      Depth                                               \
# Date              1.1.1967 1.1.1969 1.1.1970 1.1.1971 1.1.1972 1.1.1973
# Type
# Earthquake            30.0     45.0     35.0     35.0     10.0     33.0
# Explosion              NaN      NaN      NaN      NaN      NaN      NaN
# Nuclear Explosion      NaN      NaN      NaN      NaN      NaN      NaN
# Rock Burst             NaN      NaN      NaN      NaN      NaN      NaN
#
#                                                          ... Magnitude  \
# Date              1.1.1975 1.1.1976   1.1.1977 1.1.1980  ...  9.9.2005
# Type                                                     ...
# Earthquake            43.0    41.75  57.666667     10.0  ...     6.175
# Explosion              NaN      NaN        NaN      NaN  ...       NaN
# Nuclear Explosion      NaN      NaN        NaN      NaN  ...       NaN
# Rock Burst             NaN      NaN        NaN      NaN  ...       NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error',
#        'Depth Seismic Stations', 'Magnitude', 'Magnitude Type',
#        'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap',
#        'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID',
#        'Source', 'Location Source', 'Magnitude Source', 'Status', 'category'],
#       dtype='object')

# %%
melted_data = pd.melt(df, id_vars=['Date', 'Time','Type'],
                      value_vars=['Depth'],
                      var_name='Depth',value_name='Depth_km')
melted_data #დროის მიხედვით რა სიღრმისა და ტიპის შემთხვევებია. მაგალითად 1965 ში მომხდარი შემთხვევა რა სახის იყო
# და მისი სიღრმე
# Out:
#              Date      Time        Type  Depth  Depth_km
# 0        1.2.1965  13:44:18  Earthquake  Depth    131.60
# 1        1.4.1965  11:29:49  Earthquake  Depth     80.00
# 2        1.5.1965  18:05:58  Earthquake  Depth     20.00
# 3        1.8.1965  18:49:43  Earthquake  Depth     15.00
# 4        1.9.1965  13:32:50  Earthquake  Depth     15.00
# ...           ...       ...         ...    ...       ...
# 23407  12.28.2016   8:22:12  Earthquake  Depth     12.30
# 23408  12.28.2016   9:13:47  Earthquake  Depth      8.80
# 23409  12.28.2016  12:38:51  Earthquake  Depth     10.00
# 23410  12.29.2016  22:30:19  Earthquake  Depth     79.00
# 23411  12.30.2016  20:08:28  Earthquake  Depth     11.94
#
# [23412 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 4))
sns.histplot(df['Magnitude'], bins=20, kde=False)
plt.title('Distribution of Earthquake Magnitudes')
plt.xlabel('Magnitudes')
plt.ylabel('Frequency')
plt.show() #მაგნიტუდების მიხედვით მიწისძვრების სიხშირე

# %%
type_counts = df['Type'].value_counts()

plt.figure(figsize=(8, 6))
plt.pie(type_counts, labels=type_counts.index, autopct='%.1f%%', startangle=90)
plt.legend(labels=type_counts.index, loc='upper right')
plt.title('Distribution of Earthquake Types')
plt.show()
# მიწისძვრის ტიპების სიხშირე

# %%
categories_counts = df.category.value_counts()
categories_counts

plt.figure(figsize=(10, 6))  # Adjust figure size if needed
bars = plt.bar(categories_counts.index, categories_counts.values)

plt.xlabel('Depth Categories')
plt.ylabel('Count')
plt.title('Distribution of Earthquake Depth')

plt.legend(bars, type_counts.index, loc='upper right')

plt.show() # მიწისძვრის სიღრმის სიხშირე

# %%
df[['Day', 'Month', 'Year']] = df['Date'].str.split('.', expand=True)
df #დეით სვეტი 3 ნაწილად გავყავი , რომ შემდეგ წლის სვეტი ცალკე გამომეყენებინა
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1.2.1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1.4.1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1.5.1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1.8.1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1.9.1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12.28.2016   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12.28.2016   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12.28.2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12.29.2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12.30.2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.Depth.value_counts()
# Out:
# Depth
# 10.000     3911
# 33.000     3694
# 35.000      592
# 15.000      384
# 20.000      336
#            ...
# 9.856         1
# 146.400       1
# 135.700       1
# 454.000       1
# 11.940        1
# Name: count, Length: 3485, dtype: int64

# %%
years = df.Year
depths = df.Depth

plt.figure(figsize=(10, 6))
plt.scatter(years, depths, color='blue', marker='o', s=50, alpha=0.75)

plt.title('Earthquake Depths Over Years')
plt.xlabel('Years')
plt.ylabel('Depth (km)')
plt.grid(True)

plt.tight_layout()
plt.show() # წლების განმავლობაში მიწისძვრის სიღრმის მაჩვენებელი

# %%
df.Date = df.Date.astype(str)
df.Time = df.Time.astype(str)

df['Datetime'] = pd.to_datetime(df.Date + ' ' + df.Time, errors='coerce')
df
# Out:
# <ipython-input-115-15baa984076e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Date = df.Date.astype(str)
# <ipython-input-115-15baa984076e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Time = df.Time.astype(str)
# <ipython-input-115-15baa984076e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.set_index('Datetime', inplace=True)

df = df[df.index.notnull()]

df.Year = df.index.year
df.Month = df.index.month
df.Day = df.index.day
df.Weekday = df.index.dayofweek

average_magnitude_per_month = df.resample('M')['Magnitude'].mean()
print(average_magnitude_per_month)#ყოველთვიურად საშუალო მაგნიტუდის მაჩვენებელი
# Out:
# Datetime
# 1965-01-31    6.123077
# 1965-02-28    5.955556
# 1965-03-31    6.057895
# 1965-04-30    5.945455
# 1965-05-31    5.954545
#                 ...
# 2016-08-31    5.945714
# 2016-09-30    5.805217
# 2016-10-31    5.827778
# 2016-11-30    5.906818
# 2016-12-31    5.977358
# Freq: M, Name: Magnitude, Length: 624, dtype: float64
# <ipython-input-116-fc3b31fb0ee3>:8: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.Weekday = df.index.dayofweek
